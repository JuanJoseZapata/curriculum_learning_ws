# %%
import argparse
import importlib
import os
import random
import time
from distutils.util import strtobool

import gymnasium as gym
import numpy as np
import supersuit as ss
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.normal import Normal
from torch.distributions.categorical import Categorical
from torch.utils.tensorboard import SummaryWriter

from gym_multi_car_racing import multi_car_racing_bezier
from vector.vector_constructors import concat_vec_envs


def parse_args():
    # fmt: off
    parser = argparse.ArgumentParser(allow_abbrev=False)

    # Algorithm specific arguments
    parser.add_argument("--env-id", type=str, default="multi_car_racing",
        help="the id of the environment")
    parser.add_argument("--seed", type=int, default=123,
        help="seed of the experiment")
    parser.add_argument("--torch-deterministic", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
        help="if toggled, `torch.backends.cudnn.deterministic=False`")
    parser.add_argument("--cuda", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="if toggled, cuda will be enabled by default")
    parser.add_argument("--num-episodes", type=int, default=10,
        help="number of episodes to test")
    parser.add_argument("--model-path", type=str, default=None,
        help="path to the model to be tested")
    parser.add_argument("--track-name", type=str, default=None,
        help="Formula 1 track name")
    parser.add_argument("--num-agents", type=int, default=2,
        help="number of agents in the environment")
    parser.add_argument("--frame-stack", type=int, default=4,
        help="number of stacked frames")
    parser.add_argument("--frame-skip", type=float, default=4,
        help="number of frames to skip (repeat action)")
    parser.add_argument("--num-envs", type=int, default=16,  # 16
        help="the number of parallel game environments")
    parser.add_argument("--discrete-actions", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
        help="Whether to use a discrete action space")
    parser.add_argument("--render", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
        help="Whether to render the environment")
    args, unknown = parser.parse_known_args()
    # fmt: on
    return args


def make_env():

    render_mode = "human" if args.render else "state_pixels"

    # env setup
    env = multi_car_racing_bezier.parallel_env(n_agents=args.num_agents, render_mode=render_mode,
                                               use_random_direction=False,
                                               discrete_action_space=args.discrete_actions, verbose=0)
    
    if not args.discrete_actions:
        env = ss.clip_actions_v0(env)
    if args.frame_skip > 1:
        env = ss.frame_skip_v0(env, args.frame_skip)
    if args.frame_stack > 1:
        env = ss.frame_stack_v1(env, args.frame_stack)
    if args.clip_rewards:
        env.render_mode = None
        env = ss.clip_reward_v0(env, lower_bound=-3, upper_bound=3)
    env = ss.pettingzoo_env_to_vec_env_v1(env)

    return env


def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, envs):
        super().__init__()
        self.network = nn.Sequential(
            layer_init(nn.Conv2d(12, 32, 8, stride=4)),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 4, stride=2)),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
            layer_init(nn.Linear(64 * 7 * 7, 512)),
            nn.ReLU(),
        )
        if args.discrete_actions:
            self.actor = layer_init(nn.Linear(512, envs.single_action_space.n), std=0.01)
            self.critic = layer_init(nn.Linear(512, 1), std=1)
        else:
            self.actor_mean = layer_init(nn.Linear(512, np.prod(envs.single_action_space.shape)), std=0.01)
            self.actor_logstd = nn.Parameter(torch.zeros(1, np.prod(envs.single_action_space.shape)))
            self.critic = layer_init(nn.Linear(512, 1), std=1)

    def get_value(self, x):
        return self.critic(self.network(x.permute((0, 3, 1, 2)) / 255.0))

    def get_action_and_value(self, x, action=None):
        hidden = self.network(x.permute((0, 3, 1, 2)) / 255.0)
        if args.discrete_actions:
            logits = self.actor(hidden)
            probs = Categorical(logits=logits)
            if action is None:
                action = probs.sample()
            return action, probs.log_prob(action), probs.entropy(), self.critic(hidden)
        else:
            action_mean = self.actor_mean(hidden)
            action_logstd = self.actor_logstd.expand_as(action_mean)
            action_std = torch.exp(action_logstd)
            probs = Normal(action_mean, action_std)
            if action is None:
                action = probs.sample()
            return action, probs.log_prob(action).sum(1), probs.entropy().sum(1), self.critic(hidden)

# %%
# Enable autoreload
# %load_ext autoreload

# %%
# Load tracks
X = np.load("X.npy")
X = X*30  # Rescale
X.shape
# Out:
# (20000, 12, 2)

# %%
# %autoreload 2

# %%
def map_envs_to_pipes(idx_starts, num_envs):
    num_pipes = len(idx_starts) - 1
    envs_per_pipe = int(np.ceil(num_envs / num_pipes))

    envs_pipes = np.ones((num_pipes, envs_per_pipe))*(-1)

    for i in range(envs_pipes.shape[0]):
        envs_pipes[i, :] = np.arange(idx_starts[i], idx_starts[i+1])
    
    return envs_pipes

def get_env_position(env_num, envs_pipes):
    return [e[0] for e in np.where(envs_pipes == env_num)]

def set_control_points(envs, env_num, control_points):
    envs_pipes = map_envs_to_pipes(envs.idx_starts, envs.num_envs)
    pipe, pos = get_env_position(env_num, envs_pipes)
    envs.pipes[pipe].send(("set_control_points", (pos, control_points)))
    envs.pipes[pipe].recv()

# %%
args = parse_args()

args.model_path = "multi_car_racing__20231012__20231012_154400_2640000.pt"
args.num_agents = 1
args.num_envs = 5
args.render = False
args.clip_rewards = False
args.num_cpus = 8

print(args)

# TRY NOT TO MODIFY: seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
print("Device:", device)

# env setup
envs = concat_vec_envs(make_env, args.num_envs, num_cpus=args.num_cpus)
print("Observation space:", envs.observation_space)
print("Action space:", envs.action_space)
envs.single_observation_space = envs.observation_space
envs.single_action_space = envs.action_space
envs.is_vector_env = True
envs.single_observation_space = envs.observation_space
envs.single_action_space = envs.action_space
envs.is_vector_env = True

agent = Agent(envs).to(device)
agent.load_state_dict(torch.load(args.model_path))

# Run
if os.path.exists("returns.npy"):
    returns = np.load("returns.npy")
else:
    returns = np.zeros((X.shape[0], args.num_envs))

# Start track
start_index = 19950

# Set first track
for i in range(args.num_envs):
    set_control_points(envs, i, X[start_index])

next_obs, info = envs.reset(seed=args.seed)
next_obs = torch.Tensor(next_obs).to(device)
episode_return = np.zeros(args.num_envs)
episode_length = np.zeros(args.num_envs).astype(int)

total_track_count = 0
envs_track_count = np.ones(args.num_envs).astype(int)*(start_index - 1)  # -1 because the first track is done twice for some reason

while total_track_count < 20_000:

    action, _, _, _ = agent.get_action_and_value(next_obs)
    next_obs, reward, done, truncation, info = envs.step(action.cpu().numpy())
    next_obs = torch.Tensor(next_obs).to(device)
    episode_return += reward
    episode_length += 1

    for i in range(args.num_envs):
        if done[i]:
            # Add results to arrays
            if envs_track_count[i] != -1:
                returns[envs_track_count[i], i] = episode_return[i]
            print(f"Env {i} done with track {envs_track_count[i]}, reward: {episode_return[i]}, length: {episode_length[i]}")
            # Increase counters
            envs_track_count[i] += 1
            # Set new track
            set_control_points(envs, i, X[envs_track_count[i]+1])
            # Reset episode
            episode_length[i] = 0
            episode_return[i] = 0

    total_track_count = np.min(envs_track_count)

    # Save every 50 tracks
    if total_track_count % 50 == 0:
        np.save("returns.npy", returns)
# Out:
# Namespace(clip_rewards=False, cuda=True, discrete_actions=False, env_id='multi_car_racing', frame_skip=4, frame_stack=4, model_path='multi_car_racing__20231012__20231012_154400_2640000.pt', num_agents=1, num_cpus=8, num_envs=5, num_episodes=10, render=False, seed=123, torch_deterministic=False, track_name=None)
# Device: cuda
# Observation space: Box(0, 255, (84, 84, 12), uint8)
# Action space: Box([-1.  0.  0.], 1.0, (3,), float32)
# Env 0 done with track 19949, reward: 423.4042736515403, length: 251
# Env 1 done with track 19949, reward: 224.68632515519857, length: 251
# Env 2 done with track 19949, reward: 376.3957260251045, length: 251
# Env 3 done with track 19949, reward: 352.89145135879517, length: 251
# Env 4 done with track 19949, reward: 380.66923021525145, length: 251
# Env 0 done with track 19950, reward: 235.37008552998304, length: 251
# Env 1 done with track 19950, reward: 423.4042735621333, length: 251
# Env 2 done with track 19950, reward: 408.44700661301613, length: 251
# Env 3 done with track 19950, reward: 164.8572642430663, length: 251
# Env 4 done with track 19950, reward: 434.08803417533636, length: 251
# Env 0 done with track 19951, reward: 380.6692294180393, length: 251
# Env 1 done with track 19951, reward: 348.6179484948516, length: 251
# Env 2 done with track 19951, reward: 502.46410086005926, length: 251
# Env 3 done with track 19951, reward: 241.7803419753909, length: 251
# Env 4 done with track 19951, reward: 399.90000300854445, length: 251
# Env 0 done with track 19952, reward: 534.5153849348426, length: 251
# Env 1 done with track 19952, reward: 521.6948707029223, length: 251
# Env 2 done with track 19952, reward: 476.8230757638812, length: 251
# Env 3 done with track 19952, reward: 468.2760665640235, length: 251
# Env 4 done with track 19952, reward: 429.8145285472274, length: 251
# Env 0 done with track 19953, reward: 696.9085437878966, length: 251
# Env 1 done with track 19953, reward: 498.1905938908458, length: 251
# Env 2 done with track 19953, reward: 581.5239280462265, length: 251
# Env 3 done with track 19953, reward: 728.9598262235522, length: 251
# Env 4 done with track 19953, reward: 551.6093971952796, length: 251
# Env 0 done with track 19954, reward: 566.5666634738445, length: 251
# Env 1 done with track 19954, reward: 662.7205114066601, length: 251
# Env 2 done with track 19954, reward: 517.4213669002056, length: 251
# Env 3 done with track 19954, reward: 560.1564083918929, length: 251
# Env 4 done with track 19954, reward: 528.1051266416907, length: 251
# Env 0 done with track 19955, reward: 532.378632478416, length: 251
# Env 1 done with track 19955, reward: 523.8316216394305, length: 251
# Env 2 done with track 19955, reward: 496.0538432225585, length: 251
# Env 3 done with track 19955, reward: 607.1649550795555, length: 251
# Env 4 done with track 19955, reward: 489.6435874328017, length: 251
# Env 0 done with track 19956, reward: 231.0965806543827, length: 251
# Env 1 done with track 19956, reward: 496.053846322, length: 251
# Env 2 done with track 19956, reward: 600.754696957767, length: 251
# Env 3 done with track 19956, reward: 579.3871771916747, length: 251
# Env 4 done with track 19956, reward: 271.6948719844222, length: 251
# Env 0 done with track 19957, reward: 451.1820479631424, length: 251
# Env 1 done with track 19957, reward: 423.40427269786596, length: 251
# Env 2 done with track 19957, reward: 402.03674956411123, length: 251
# Env 3 done with track 19957, reward: 252.4640998467803, length: 251
# Env 4 done with track 19957, reward: 615.7119621559978, length: 251
# Env 0 done with track 19958, reward: 419.1307682618499, length: 251
# Env 1 done with track 19958, reward: 152.03675188869238, length: 251
# Env 2 done with track 19958, reward: 534.5153820216656, length: 251
# Env 3 done with track 19958, reward: 613.5752120539546, length: 251
# Env 4 done with track 19958, reward: 607.1649557054043, length: 251
# Env 0 done with track 19959, reward: 673.4042667970061, length: 251
# Env 1 done with track 19959, reward: 577.2504258155823, length: 251
# Env 2 done with track 19959, reward: 581.5239293202758, length: 251
# Env 3 done with track 19959, reward: 647.7632456347346, length: 251
# Env 4 done with track 19959, reward: 508.87435817718506, length: 251
# Env 0 done with track 19960, reward: 493.9170911312103, length: 251
# Env 1 done with track 19960, reward: 414.8572630509734, length: 251
# Env 2 done with track 19960, reward: 404.17350270599127, length: 251
# Env 3 done with track 19960, reward: 391.35298892110586, length: 251
# Env 4 done with track 19960, reward: 177.67777713388205, length: 251
# Env 0 done with track 19961, reward: 312.2931620180607, length: 251
# Env 1 done with track 19961, reward: 192.63504164665937, length: 251
# Env 2 done with track 19961, reward: 436.2247888967395, length: 251
# Env 3 done with track 19961, reward: 498.19060092419386, length: 251
# Env 4 done with track 19961, reward: 449.04530089348555, length: 251
# Env 0 done with track 19962, reward: 278.1051254197955, length: 251
# Env 1 done with track 19962, reward: 337.93418883532286, length: 251
# Env 2 done with track 19962, reward: 414.8572626635432, length: 251
# Env 3 done with track 19962, reward: 500.3273491859436, length: 251
# Env 4 done with track 19962, reward: 374.25897251814604, length: 251
# Env 0 done with track 19963, reward: 438.3615394756198, length: 251
# Env 1 done with track 19963, reward: 378.53248056024313, length: 251
# Env 2 done with track 19963, reward: 290.9256414398551, length: 251
# Env 3 done with track 19963, reward: 414.8572647497058, length: 251
# Env 4 done with track 19963, reward: 472.5495734810829, length: 251
# Env 0 done with track 19964, reward: 474.686325751245, length: 251
# Env 1 done with track 19964, reward: 393.4897466227412, length: 251
# Env 2 done with track 19964, reward: 406.31025736778975, length: 251
# Env 3 done with track 19964, reward: 402.0367523357272, length: 251
# Env 4 done with track 19964, reward: 342.2076913639903, length: 251
# Env 0 done with track 19965, reward: 498.1905955299735, length: 251
# Env 1 done with track 19965, reward: 498.19059600681067, length: 251
# Env 2 done with track 19965, reward: 555.8829041048884, length: 251
# Env 3 done with track 19965, reward: 624.2589701041579, length: 251
# Env 4 done with track 19965, reward: 513.1478600725532, length: 251
# Env 0 done with track 19966, reward: 382.80598210543394, length: 251
# Env 1 done with track 19966, reward: 280.2418776154518, length: 251
# Env 2 done with track 19966, reward: 389.216238103807, length: 251
# Env 3 done with track 19966, reward: 536.6521350070834, length: 251
# Env 4 done with track 19966, reward: 538.7888878509402, length: 251
# Env 0 done with track 19967, reward: 299.4726502597332, length: 251
# Env 1 done with track 19967, reward: 427.6777796447277, length: 251
# Env 2 done with track 19967, reward: 252.46410366147757, length: 251
# Env 3 done with track 19967, reward: 342.2076928243041, length: 251
# Env 4 done with track 19967, reward: 305.88290663808584, length: 251
# Env 0 done with track 19968, reward: 476.8230769261718, length: 251
# Env 1 done with track 19968, reward: 694.7717932388186, length: 251
# Env 2 done with track 19968, reward: 628.5324779674411, length: 251
# Env 3 done with track 19968, reward: 536.6521361768246, length: 251
# Env 4 done with track 19968, reward: 543.062390498817, length: 251
# Env 0 done with track 19969, reward: 570.8401688635349, length: 251
# Env 1 done with track 19969, reward: 457.5923047289252, length: 251
# Env 2 done with track 19969, reward: 224.68632443994284, length: 251
# Env 3 done with track 19969, reward: 536.6521339118481, length: 251
# Env 4 done with track 19969, reward: 214.0025634765625, length: 251
# Env 0 done with track 19970, reward: 201.1820514127612, length: 251
# Env 1 done with track 19970, reward: 350.7547008320689, length: 251
# Env 2 done with track 19970, reward: 350.75470154732466, length: 251
# Env 3 done with track 19970, reward: 314.4299144670367, length: 251
# Env 4 done with track 19970, reward: 312.29316257685423, length: 251
# Env 0 done with track 19971, reward: 481.0965802371502, length: 251
# Env 1 done with track 19971, reward: 534.5153831169009, length: 251
# Env 2 done with track 19971, reward: 540.925639770925, length: 251
# Env 3 done with track 19971, reward: 528.1051264330745, length: 251
# Env 4 done with track 19971, reward: 284.51538383215666, length: 251
# Env 0 done with track 19972, reward: 504.6008506938815, length: 251
# Env 1 done with track 19972, reward: 570.8401707336307, length: 251
# Env 2 done with track 19972, reward: 543.0623915717006, length: 251
# Env 3 done with track 19972, reward: 489.64358877390623, length: 251
# Env 4 done with track 19972, reward: 585.7974349856377, length: 251
# Env 0 done with track 19973, reward: 395.62649696320295, length: 251
# Env 1 done with track 19973, reward: 404.17350252717733, length: 251
# Env 2 done with track 19973, reward: 444.7717946097255, length: 251
# Env 3 done with track 19973, reward: 355.0282048508525, length: 251
# Env 4 done with track 19973, reward: 416.99401780217886, length: 251
# Env 0 done with track 19974, reward: 434.0880348905921, length: 251
# Env 1 done with track 19974, reward: 572.9769208356738, length: 251
# Env 2 done with track 19974, reward: 489.6435878202319, length: 251
# Env 3 done with track 19974, reward: 476.82307582348585, length: 251
# Env 4 done with track 19974, reward: 592.2076916918159, length: 251
# Env 0 done with track 19975, reward: 226.82307647913694, length: 251
# Env 1 done with track 19975, reward: 517.4213645979762, length: 251
# Env 2 done with track 19975, reward: 590.0709355399013, length: 251
# Env 3 done with track 19975, reward: 511.0111085996032, length: 251
# Env 4 done with track 19975, reward: 579.3871783539653, length: 251
# Env 0 done with track 19976, reward: 397.7632458433509, length: 251
# Env 1 done with track 19976, reward: 425.54102393239737, length: 251
# Env 2 done with track 19976, reward: 472.54957062005997, length: 251
# Env 3 done with track 19976, reward: 380.6692276522517, length: 251
# Env 4 done with track 19976, reward: 525.9683747887611, length: 251
# Env 0 done with track 19977, reward: 652.0367500707507, length: 251
# Env 1 done with track 19977, reward: 538.788889311254, length: 251
# Env 2 done with track 19977, reward: 572.9769222661853, length: 251
# Env 3 done with track 19977, reward: 579.3871793672442, length: 251
# Env 4 done with track 19977, reward: 572.9769205376506, length: 251
# Env 0 done with track 19978, reward: 513.1478627324104, length: 251
# Env 1 done with track 19978, reward: 547.3358981013298, length: 251
# Env 2 done with track 19978, reward: 431.95128264278173, length: 251
# Env 3 done with track 19978, reward: 513.1478641331196, length: 251
# Env 4 done with track 19978, reward: 517.4213678240776, length: 251
# Env 0 done with track 19979, reward: 333.66068448871374, length: 251
# Env 1 done with track 19979, reward: 406.3102557659149, length: 251
# Env 2 done with track 19979, reward: 397.7632488235831, length: 251
# Env 3 done with track 19979, reward: 399.8999999091029, length: 251
# Env 4 done with track 19979, reward: 322.97692384570837, length: 251
# Env 0 done with track 19980, reward: 622.1222186014056, length: 251
# Env 1 done with track 19980, reward: 275.9683757945895, length: 251
# Env 2 done with track 19980, reward: 485.3700832054019, length: 251
# Env 3 done with track 19980, reward: 278.1051264330745, length: 251
# Env 4 done with track 19980, reward: 372.12222223728895, length: 251
# Env 0 done with track 19981, reward: 446.9085469469428, length: 251
# Env 1 done with track 19981, reward: 393.48974388837814, length: 251
# Env 2 done with track 19981, reward: 515.2846128568053, length: 251
# Env 3 done with track 19981, reward: 498.19059762358665, length: 251
# Env 4 done with track 19981, reward: 374.25897332280874, length: 251
# Env 0 done with track 19982, reward: 521.6948729678988, length: 251
# Env 1 done with track 19982, reward: 423.4042743444443, length: 251
# Env 2 done with track 19982, reward: 493.91709407418966, length: 251
# Env 3 done with track 19982, reward: 515.284614764154, length: 251
# Env 4 done with track 19982, reward: 489.6435899063945, length: 251
# Env 0 done with track 19983, reward: 513.1478593349457, length: 251
# Env 1 done with track 19983, reward: 269.5581212863326, length: 251
# Env 2 done with track 19983, reward: 487.50683503597975, length: 251
# Env 3 done with track 19983, reward: 402.0367522165179, length: 251
# Env 4 done with track 19983, reward: 562.2931595146656, length: 251
# Env 0 done with track 19984, reward: 555.8829038962722, length: 251
# Env 1 done with track 19984, reward: 472.54957403987646, length: 251
# Env 2 done with track 19984, reward: 605.0282057747245, length: 251
# Env 3 done with track 19984, reward: 583.6606816872954, length: 251
# Env 4 done with track 19984, reward: 543.0623907968402, length: 251
# Env 0 done with track 19985, reward: 239.6435868665576, length: 251
# Env 1 done with track 19985, reward: 530.2418776676059, length: 251
# Env 2 done with track 19985, reward: 534.5153821334243, length: 251
# Env 3 done with track 19985, reward: 511.0111083611846, length: 251
# Env 4 done with track 19985, reward: 579.387177221477, length: 251
# Env 0 done with track 19986, reward: 517.4213665947318, length: 251
# Env 1 done with track 19986, reward: 209.729059509933, length: 251
# Env 2 done with track 19986, reward: 205.45555441826582, length: 251
# Env 3 done with track 19986, reward: 397.7632454931736, length: 251
# Env 4 done with track 19986, reward: 164.8572647497058, length: 251
# Env 0 done with track 19987, reward: 489.64358853548765, length: 251
# Env 1 done with track 19987, reward: 436.22478883713484, length: 251
# Env 2 done with track 19987, reward: 397.7632460221648, length: 251
# Env 3 done with track 19987, reward: 619.9854656085372, length: 251
# Env 4 done with track 19987, reward: 630.6692263707519, length: 251
# Env 0 done with track 19988, reward: 538.788882933557, length: 251
# Env 1 done with track 19988, reward: 716.1393102928996, length: 251
# Env 2 done with track 19988, reward: 615.7119625136256, length: 251
# Env 3 done with track 19988, reward: 602.8914479836822, length: 251
# Env 4 done with track 19988, reward: 570.8401664197445, length: 251
# Env 0 done with track 19989, reward: 523.8316217362881, length: 251
# Env 1 done with track 19989, reward: 602.8914507254958, length: 251
# Env 2 done with track 19989, reward: 525.9683735594153, length: 251
# Env 3 done with track 19989, reward: 607.1649519726634, length: 251
# Env 4 done with track 19989, reward: 568.7034180685878, length: 251
# Env 0 done with track 19990, reward: 613.5752113685012, length: 251
# Env 1 done with track 19990, reward: 481.09657898545265, length: 251
# Env 2 done with track 19990, reward: 585.7974359616637, length: 251
# Env 3 done with track 19990, reward: 605.0282040163875, length: 251
# Env 4 done with track 19990, reward: 609.3017087802291, length: 251
# Env 0 done with track 19991, reward: 572.976921223104, length: 251
# Env 1 done with track 19991, reward: 536.6521308943629, length: 251
# Env 2 done with track 19991, reward: 391.3529887124896, length: 251
# Env 3 done with track 19991, reward: 461.8658092021942, length: 251
# Env 4 done with track 19991, reward: 470.41281708329916, length: 251
# Env 0 done with track 19992, reward: 365.711965046823, length: 251
# Env 1 done with track 19992, reward: 380.6692312285304, length: 251
# Env 2 done with track 19992, reward: 331.5239309594035, length: 251
# Env 3 done with track 19992, reward: 337.9341880604625, length: 251
# Env 4 done with track 19992, reward: 314.42991399019957, length: 251
# Env 0 done with track 19993, reward: 427.67777740210295, length: 251
# Env 1 done with track 19993, reward: 464.00256084650755, length: 251
# Env 2 done with track 19993, reward: 352.8914507254958, length: 251
# Env 3 done with track 19993, reward: 314.42991327494383, length: 251
# Env 4 done with track 19993, reward: 408.44700542092323, length: 251
# Env 0 done with track 19994, reward: 496.0538447126746, length: 251
# Env 1 done with track 19994, reward: 523.8316241726279, length: 251
# Env 2 done with track 19994, reward: 468.27606716006994, length: 251
# Env 3 done with track 19994, reward: 231.09658085554838, length: 251
# Env 4 done with track 19994, reward: 348.61794724315405, length: 251
# Env 0 done with track 19995, reward: 555.882902674377, length: 251
# Env 1 done with track 19995, reward: 545.1991432532668, length: 251
# Env 2 done with track 19995, reward: 681.9512772262096, length: 251
# Env 3 done with track 19995, reward: 530.2418743595481, length: 251
# Env 4 done with track 19995, reward: 645.6264905557036, length: 251
# Env 0 done with track 19996, reward: 301.60940071195364, length: 251
# Env 1 done with track 19996, reward: 416.99401738494635, length: 251
# Env 2 done with track 19996, reward: 444.7717936858535, length: 251
# Env 3 done with track 19996, reward: 196.90854620188475, length: 251
# Env 4 done with track 19996, reward: 190.4982896670699, length: 251
# Env 0 done with track 19997, reward: 581.5239312872291, length: 251
# Env 1 done with track 19997, reward: 525.9683756530285, length: 251
# Env 2 done with track 19997, reward: 464.00256406515837, length: 251
# Env 3 done with track 19997, reward: 553.7461532354355, length: 251
# Env 4 done with track 19997, reward: 466.13931611180305, length: 251
# Env 0 done with track 19998, reward: 575.1136723384261, length: 251
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 73
#      71 envs_track_count[i] += 1
#      72 # Set new track
# ---> 73 set_control_points(envs, i, X[envs_track_count[i]+1])
#      74 # Reset episode
#      75 episode_length[i] = 0
#
# IndexError: index 20000 is out of bounds for axis 0 with size 20000

# %%
# %autoreload 2

# %%
returns = np.load("returns.npy")

# %%
# Filter rows that are not zeros
num_done_tracks = returns[~np.all(returns == 0, axis=1)].shape[0]
num_done_tracks
# Out:
# 12000

# %%
from gym_multi_car_racing import bezier
from gymnasium.utils import seeding
import matplotlib.pyplot as plt

np_random, seed = seeding.np_random(7)

def get_track(control_points=None, np_random=np_random):
    if control_points is not None:
        a = np.array(control_points)
        x, y, _ = bezier.get_bezier_curve(a=a, rad=0.2, edgy=0.2, numpoints=40)
    else:
        a = bezier.get_random_points(n=12, scale=PLAYFIELD, mindst=None, np_random=np_random) // 30 * 30
        x, y, _ = bezier.get_bezier_curve(a=a, rad=0.2, edgy=0.2, numpoints=40)

    x, y = np.clip(0, x.max(), x), np.clip(0, y.max(), y)

    return a, x, y

def plot_track(track, checkpoints=None):
    # Plot track
    plt.plot(track[:,1], track[:,0], linewidth=9, color=[0.4, 0.4, 0.4])

    # Plot checkpoints
    if checkpoints is not None:
        for i in range(len(checkpoints)):
            y, x = checkpoints[i,:]
            plt.plot(x, y, 'o', markersize=2, color="tab:orange")
            plt.text(x, y, str(i), fontsize=10, color="black")
    
    plt.xlim(-20,360)
    plt.ylim(-20,360)

    ax = plt.gca()
    ax.set_facecolor(np.array([102, 230, 102])/255.)

from PIL import Image, ImageDraw
import numpy as np
import cv2

def get_image_(points, img_size=(32, 32)):
    """
    Create a 2D image of a curve using a set of points.

    Parameters:
    - points: List of tuples representing (x, y) coordinates of the curve.
    - img_size: Tuple representing the size of the image (width, height).

    Returns:
    - img_array: NumPy array representing the image.

    Example:
    >>> points = [(0, 0), (1, 1), (2, 4), (3, 9), (4, 16)]
    >>> image_array = get_image(points)
    """
    # Find the bounding box of the points
    min_x, min_y = np.min(points, axis=0)
    max_x, max_y = np.max(points, axis=0)

    # Create a blank image with a black background
    width = int(max_x - min_x) + 20
    height = int(max_y - min_y) + 20
    image = Image.new("RGB", (width, height), "black")
    draw = ImageDraw.Draw(image)

    # Translate points to the image coordinates
    translated_points = [(x - min_x + 10, y - min_y + 10) for x, y in points]

    # Draw the curve on the image
    draw.line(translated_points, fill="white", width=2)

    # Convert the PIL image to a NumPy array
    img_array = np.array(image)

    # Convert to grayscale
    img_array = np.mean(img_array, axis=2)

    # Resize image
    width, height = img_size
    img_array = cv2.resize(img_array, dsize=(width, height), interpolation=cv2.INTER_AREA)

    # Normalize pixel values
    img_array = img_array / img_array.max()

    return img_array

# %%
complexities = np.load("complexities.npy")

# %%
indices = np.random.choice(np.where(returns.mean(axis=1) > 0)[0], size=9, replace=False)
indices = np.random.choice(np.where((returns.mean(axis=1) < 370) & (np.array(returns).mean(axis=1) > 0))[0], size=9, replace=False)
#indices = np.arange(start_index, start_index + 9)

plt.figure(figsize=(7,7))

for i, index in enumerate(indices):
    plt.subplot(3,3,i+1)
    checkpoints, x, y = get_track(control_points=X[index])
    track = np.array([x, y]).T
    img = get_image_(track, img_size=(48, 48))
    plt.imshow(img)
    plt.title(f"{index} Return: {np.array(returns).mean(axis=1)[index]:1.0f}")
    plt.axis('off')
plt.tight_layout()

# %%
index = 28

checkpoints, x, y = get_track(control_points=control_points[index])
track = np.array([x, y]).T
img = get_image_(track, img_size=(48, 48))
plt.imshow(img)
plt.title(f"{index} Return: {returns[index]:1.0f}")
plt.axis('off')
# Out:
# (-0.5, 47.5, 47.5, -0.5)
